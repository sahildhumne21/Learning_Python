# %%
import pandas as pd
import numpy as np

# %%
country=["india","pakistan","usa","america","nepal"]
pd.Series(country)
# Out:
# 0       india
# 1    pakistan
# 2         usa
# 3     america
# 4       nepal
# dtype: object

# %%
runs=[23,43,55,67,87,43,23,11]

runs_series=pd.Series(runs)
runs_series
# Out:
# 0    23
# 1    43
# 2    55
# 3    67
# 4    87
# 5    43
# 6    23
# 7    11
# dtype: int64

# %%
marks=[90,60,70,88,89,97]
subjects=["maths","science","chemistry","biology","history","marathi"]

pd.Series(marks,index=subjects)
# Out:
# maths        90
# science      60
# chemistry    70
# biology      88
# history      89
# marathi      97
# dtype: int64

# %%
marks=pd.Series(marks,index=subjects,name="sahil ke marks")
marks
# Out:
# maths        90
# science      60
# chemistry    70
# biology      88
# history      89
# marathi      97
# Name: sahil ke marks, dtype: int64

# %%
marks={
    "marks":89,
    "marathi":97,
    "maths":88,
    "science":66,
    "biology":77
}

marks_series=pd.Series(marks ,name="sahil ke marks")
marks_series
# Out:
# marks      89
# marathi    97
# maths      88
# science    66
# biology    77
# Name: sahil ke marks, dtype: int64

# %%
marks_series.size
# Out:
# 5

# %%
marks_series.name
# Out:
# 'sahil ke marks'

# %%
pd.Series([1,1,2,3,4,3,2,1,2]).is_unique
# Out:
# False

# %%
runs_series.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %% [markdown]
# Series using read_csv

# %%
pd.read_csv('/content/subs.csv')
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs=pd.read_csv("/content/subs.csv")
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk=pd.read_csv("/content/kohli_ipl.csv",index_col="match_no")
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movies=pd.read_csv('/content/bollywood.csv',index_col=("movie"))
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.head(50)
# Out:
#     Subscribers gained
# 0                   48
# 1                   57
# 2                   40
# 3                   43
# 4                   44
# 5                   46
# 6                   33
# 7                   40
# 8                   44
# 9                   74
# 10                  49
# 11                  56
# 12                  49
# 13                  42
# 14                  39
# 15                  44
# 16                  54
# 17                  51
# 18                  40
# 19                  37
# 20                  40
# 21                  45
# 22                  50
# 23                  56
# 24                  35
# 25                  49
# 26                  46
# 27                  88
# 28                  61
# 29                  42
# 30                  56
# 31                  50
# 32                  50
# 33                  49
# 34                  76
# 35                 123
# 36                 108
# 37                 110
# 38                  56
# ...

# %%
movies.sample(50)
# Out:
#                                               lead
# movie
# Azhar (film)                         Emraan Hashmi
# Kyun! Ho Gaya Na...               Amitabh Bachchan
# War Chhod Na Yaar                    Sharman Joshi
# Paathshaala                           Nana Patekar
# Kurbaan (2009 film)                      Lewis Tan
# Bhaag Johnny                           Kunal Khemu
# Sholay                               Sanjeev Kumar
# Chittagong (film)                   Manoj Bajpayee
# Bubble Gum (film)                    Apoorva Arora
# Sikandar (2009 film)                Parzaan Dastur
# Home Delivery                         Vivek Oberoi
# Gully Boy                            Ranveer Singh
# Zila Ghaziabad                        Vivek Oberoi
# Vivah                                Shahid Kapoor
# Kahin Hai Mera Pyar                  Eesha Agarwal
# Sooper Se Ooper                        Tinnu Anand
# Kisaan                               Jackie Shroff
# ...

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
vk.sort_values(by='runs', ascending=False).head(1).values[0]
# Out:
# array([113])

# %%
vk.sort_values(by='runs',inplace=True)
vk
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
vk.sum()
# Out:
# runs    6634
# dtype: int64

# %%
vk.product()
# Out:
# runs    0
# dtype: int64

# %%
movies.sum()
# Out:
# lead    Vicky KaushalVicky AhujaAnupam KherEmraan Hash...
# dtype: object

# %%
vk.mean()
# Out:
# runs    30.855814
# dtype: float64

# %%
vk.min()
# Out:
# runs    0
# dtype: int64

# %%
vk.max()
# Out:
# runs    113
# dtype: int64

# %%
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
vk[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1372777673.py in <cell line: 0>()
# ----> 1 vk[1]
#
# ...

# %%
marks_series[-1]
# Out:
# /tmp/ipython-input-569294583.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   marks_series[-1]
# np.int64(77)

# %%
vk[5:16]
# Out:
#           runs
# match_no
# 207          0
# 135          0
# 130          0
# 211          0
# 106          1
# 204          1
# 113          1
# 77           1
# 1            1
# 5            1
# 75           1

# %%
marks_series[1]=100
# Out:
# /tmp/ipython-input-676866948.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=100

# %%
marks_series
# Out:
# marks       89
# marathi    100
# maths       88
# science     66
# biology     77
# Name: sahil ke marks, dtype: int64

# %%
marks_series["sst"]=100

# %%
marks
# Out:
# {'marks': 89, 'marathi': 97, 'maths': 88, 'science': 66, 'biology': 77}

# %%
marks_series[2:4]=[100,200]

# %%
marks_series
# Out:
# marks       89
# marathi    100
# maths      100
# science    200
# biology     77
# sst        100
# Name: sahil ke marks, dtype: int64

# %%
runs_series[[0,3,4]]=0

# %%
runs_series
# Out:
# 0     0
# 1    43
# 2    55
# 3     0
# 4     0
# 5    43
# 6    23
# 7    11
# dtype: int64

# %%
print(len(subs))
print(type(subs))
print(dir(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
list(marks_series)
# Out:
# [89, 100, 100, 200, 77, 100]

# %%
dict(marks_series)
# Out:
# {'marks': np.int64(89),
#  'marathi': np.int64(100),
#  'maths': np.int64(100),
#  'science': np.int64(200),
#  'biology': np.int64(77),
#  'sst': np.int64(100)}

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
"2 states(2014 film)"in movies
# Out:
# False

# %%
'Alia Bhat' in movies.values
# Out:
# False

# %%
for i in movies:
  print(i)
# Out:
# lead

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
marks_series
# Out:
# marks       89
# marathi    100
# maths      100
# science    200
# biology     77
# sst        100
# Name: sahil ke marks, dtype: int64

# %%
100-marks_series
# Out:
# marks       11
# marathi      0
# maths        0
# science   -100
# biology     23
# sst          0
# Name: sahil ke marks, dtype: int64

# %%
vk >=50
# Out:
#            runs
# match_no
# 8         False
# 87        False
# 93        False
# 91        False
# 206       False
# ...         ...
# 164        True
# 120        True
# 123        True
# 126        True
# 128        True
#
# [215 rows x 1 columns]

# %%
vk[vk==0]
# Out:
#           runs
# match_no
# 8          0.0
# 87         0.0
# 93         0.0
# 91         0.0
# 206        0.0
# ...        ...
# 164        NaN
# 120        NaN
# 123        NaN
# 126        NaN
# 128        NaN
#
# [215 rows x 1 columns]

# %%
subs[subs > 200].size
# Out:
# 365

# %%
num_movies=movies.value_counts()

# %%
num_movies[num_movies >20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>
