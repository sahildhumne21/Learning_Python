# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
# Write code here
class vehicle:
  def __init__(self,cap):
    self.seating_capacity=cap

  def charge(self):
    self.fare=self.seating_capacity*100

class bus(vehicle):

  def main_charge(self,seats):
    self.seating_capacity=seats

  def charge(self):
    print("The fare amount is :",self.seating_capacity*100 + self.seating_capacity*10)

# %%
b=bus(50)

# %%
b.charge()
# Out:
# The fare amount is : 5500

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class point:
  def __init__(self, x,y):

    self.x_axis=x
    self.y_axis=y

class loc:
  def __init__(self,location,destination):
    self.location=location
    self.destination=destination

  def reflected_on_x(self):
    reflected_x=self.location.x_axis
    reflected_y=self.location.y_axis

    print({reflected_x},{reflected_y})

loc_point = point(1, 2)
dest_point = point(3, 5)

loc_1 = loc(loc_point,dest_point)

loc_1.reflected_on_x()
# Out:
# {1} {2}

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC , abstractmethod

class polygon(ABC):

  @abstractmethod
  def area(self):
    pass


class Rectangle(polygon):
  def __init__(self,l,h):
    self.length=l
    self.height=h

  def area(self):
    print(self.length*self.height)


class Triangle(polygon):
  def __init__(self,len,b):
   self.length=len
   self.bridth=b

  def area(self):
    print(0.5*self.length*self.bridth)

# %%
tri=Triangle(3,5)

# %% [markdown]
# [link text](https:// [link text](https:// [link text](https://)))### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %% [markdown]
#  Problem-5: Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
class Bill:
  def __init__(self,amount):

    self.bill_amount=amount

  def mode(self):

    print("Press 1 to pay through cash")
    print("Press 2 to pay through cheque")


    choise=input("Enter 1/2 :")

    if choise=="1":
      cash=int(input("Enter bill to pay cash :"))
      bycash(cash,self.bill_amount)

    if choise =="2":
      cheque_amount=int(input("Enter the Cheque amount :"))
      cheque_no=int(input("Enter cheque no. :"))
      bycheque(cheque_amount,cheque_no,self.bill_amount)


class bycash(Bill):

    def __init__(self, amount,bill_amount):
      super().__init__(bill_amount)
      if amount==self.bill_amount:
        print("Bill paid succesfully")

      elif amount > self.bill_amount:
        print("remaning change is ",self.cash_tobe_pay-self.bill_amount)

      else:
        print("not paid")


class bycheque(Bill):
  def __init__(self,cheque_amount,cheque_no,bill_amount):
    super().__init__(bill_amount)
    self.cheque_no=cheque_no

    self.check_amount=cheque_amount
    if self.check_amount == self.bill_amount:
      print("PAyment done succesfully")




    else:
      print("check cancled")

# %%
b=Bill(4000)

# %%
b.mode()
# Out:
# Press 1 to pay through cash
# Press 2 to pay through cheque
# Enter 1/2 :1
# Enter bill to pay cash :4000
# Bill paid succesfully

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```
