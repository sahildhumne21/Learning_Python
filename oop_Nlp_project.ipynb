# %%
# !pip install nlpcloud

# %%
import nlpcloud

client = nlpcloud.Client("gpt-oss-120b", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f", gpu=True)
client.entities(
    """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
    searched_entity="programming languages"
)
# Out:
# {'entities': [{'start': 26,
#    'end': 36,
#    'type': 'programming languages',
#    'text': 'Javascript'},
#   {'start': 102,
#    'end': 108,
#    'type': 'programming languages',
#    'text': 'Python'},
#   {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}

# %%
import nlpcloud

client = nlpcloud.Client("python-langdetect", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f")
client.langdetection("""Et il parle aussi un peu français.""")
# Out:
# {'languages': [{'fr': 0.9999956436070834}]}

# %%
import nlpcloud

client = nlpcloud.Client("finetuned-gpt-neox-20b", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f", gpu=True, lang="en")
client.entities("""John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""", searched_entity="programming languages")
# Out:
# {'entities': [{'start': 26,
#    'end': 36,
#    'type': 'programming languages',
#    'text': 'Javascript'},
#   {'start': 102,
#    'end': 108,
#    'type': 'programming languages',
#    'text': 'Python'},
#   {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}

# %%
import nlpcloud

client = nlpcloud.Client("gpt-oss-120b", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f", gpu=True)
client.sentiment(
    """I hate convoluted products with poor documentation. I see such products all the time. But NLP Cloud is not like that!""",
    target="NLP Cloud"
)
# Out:
# {'scored_labels': [{'label': 'POSITIVE', 'score': 1},
#   {'label': 'joy', 'score': 1}]}

# %%
import nlpcloud

class NLPApp:
  def __init__(self):
    self.__Database={}
    self.__first_menu()

  def __first_menu(self):
    first_input=input("""
    Hi ! What would you like to proceed?
    1. Not a Member? Register
    2. Already a Member? Login
    3. galti se aa gaya ? Exit
    """)

    if first_input=="1":
      self.__register()
    elif first_input=="2":
      self.__login()
    else:
      exit()


  def __second_menu(self):
    second_input=input("""
    Hi ! What would you like to proceed?
    1. NER
    2. Language Detectation
    3. Sentiment Analysis
    4. Logout
    """)

    if second_input=="1":
      self.__Ner()
    elif second_input=="2":
      self.__language_detetction()
    elif second_input=="3":
      self.__sentiment_analysis()
    else:
      exit()

  def __register(self):
    name=input("Enter Your name :")
    email=input("Enter Your email :")
    password=int(input("Enter your password"))

    if email in self.__Database:
      print("email already exists")
    else:
      self.__Database[email]=[name,password]
      print("registration succesful. Now Login")
      self.__first_menu()

  def __login(self):
    email=input("Enter email :")
    password=int(input("Enter Password :"))

    if email in self.__Database:
      if self.__Database[email][1]== password:
        print("login succesfull")
        self.__second_menu()
      else:
       print("wrong password enter again :")
       self.__login()
    else:
      print("This Email is Not registered ")
      self.__first_menu

  def __Ner(self):
    para=input("Enter a Paragraph :")
    Search=input("Search the entity :")

    client = nlpcloud.Client("gpt-oss-120b", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f", gpu=True)
    Response=client.entities(para,searched_entity=Search)

    print(Response)


  def __language_detetction(self):
    para=input("Enter Paragraph :")

    client = nlpcloud.Client("python-langdetect", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f")
    response=client.langdetection,para
    print(response)

  def __sentiment_analysis(Self):
    para=input("Enter a paragraph :")

    client = nlpcloud.Client("gpt-oss-120b", "c9620211d8454dbfaa089bc2b8f473d1c568bf0f", gpu=True)
    response=client.sentiment(para)

    print(response)

obj=NLPApp()
# Out:
#     Hi ! What would you like to proceed?
#     1. Not a Member? Register
#     2. Already a Member? Login
#     3. galti se aa gaya ? Exit
#     1
# Enter Your name :sahil
# Enter Your email :sahildhumne6@gmail.com
# Enter your password3208
# registration succesful. Now Login
#
#     Hi ! What would you like to proceed?
#     1. Not a Member? Register
#     2. Already a Member? Login
#     3. galti se aa gaya ? Exit
#     2
# Enter email :sahildhumne6@gmail.com
# Enter Password :3208
# login succesfull
#
#     Hi ! What would you like to proceed?
#     1. NER
#     2. Language Detectation
#     3. Sentiment Analysis
#     4. Logout
#     3
# ...
